# %% [markdown]
# # Refer /Keras /1. preProcess with keras

# %%
import os
import gc
gc.collect()
# Out:
# 35

# %%
# https://medium.com/@jatinmandav3/opinion-mining-sometimes-known-as-sentiment-analysis-or-emotion-ai-refers-to-the-use-of-natural-874f369194c0
# Trainable kept to true for embedding here as num. OOV word were > 3000
#additional droput layer after embedding
# LSTM unit = 128

import os
from tqdm import tqdm
import pandas as pd 
import numpy as np

from keras.models import Sequential
from keras.layers import Dense, GRU,LSTM, Embedding,Flatten, Dropout,CuDNNGRU
from keras.optimizers import Adam
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
# %matplotlib inline

import pickle
import h5py

from keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras.callbacks import TensorBoard


PROJ_NAME= "3.0  Word2Vec_pretrained_300dims_20k_LSTM_trainable"

MODEL_FILEPATH = f'model_tokenizers_weights_and_json/{PROJ_NAME}_best_model.json'
WEIGHT_FILEPATH = f'model_tokenizers_weights_and_json/{PROJ_NAME}_best_weights.h5'
IMAGE_PATH = f'model_images/{PROJ_NAME}.png'
TOKENIZER_FILEPATH = f'model_tokenizers_weights_and_json/{PROJ_NAME}_tokenizer_instance.pickle'

tensorboard = TensorBoard(log_dir=f'logs/{PROJ_NAME}/')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # making it reproducable

# %%
seed = 7

np.random.seed(seed)
from tensorflow import set_random_seed
set_random_seed(seed)

# %%
INPUT_TEXT_LENGTH = 294 # from previous notebook
VOCAB_SIZE = 20000      # vocab size needs to be taken care off

# %%
df_preprocessed = pd.read_pickle("./pickles/V1_preProcessed.pkl")

# %% [markdown]
# # check if 1st 50k are shuffuled

# %%
df_preprocessed[49996:50002]
# Out:
#                                                   review  sentiment  \
# 49996  movie nothing like book think writer screenpla...        0.0
# 49997  first watched flatliners amaze necessary featu...        1.0
# 49998  see movie find hard understand many people see...        1.0
# 49999  work class romantic drama director martin ritt...        1.0
# 50000  admit great majority film release say dozen ma...        2.0
# 50001  take low budget inexperienced actor double pro...        2.0
#
#        word_count
# 49996          55
# 49997          89
# 49998          87
# 49999          92
# 50000          73
# 50001          88

# %% [markdown]
# # consider only 1st 50 for train and test split it from rest¶

# %%
df = pd.DataFrame()
df = df_preprocessed[0:49999]

# %%
df['sentiment'].value_counts()
# Out:
# 0.0    25000
# 1.0    24999
# Name: sentiment, dtype: int64

# %% [markdown]
# # Vectorising usin Keras
# - Setting integer value to a string token

# %%
# %%time 
# create the tokenizer
tokenizer =Tokenizer(num_words=VOCAB_SIZE)
# fit the tokenizer on the documents
tokenizer.fit_on_texts(df["review"])
# Out:
# Wall time: 11 s

# %%
total_vocab = tokenizer.word_index
print(total_vocab)
# Out:
# {'movie': 1, 'film': 2, 'one': 3, 'make': 4, 'like': 5, 'see': 6, 'get': 7, 'good': 8, 'time': 9, 'would': 10, 'character': 11, 'well': 12, 'go': 13, 'watch': 14, 'even': 15, 'story': 16, 'bad': 17, 'really': 18, 'think': 19, 'show': 20, 'scene': 21, 'great': 22, 'look': 23, 'much': 24, 'say': 25, 'end': 26, 'could': 27, 'know': 28, 'people': 29, 'also': 30, 'first': 31, 'give': 32, 'take': 33, 'way': 34, 'love': 35, 'act': 36, 'thing': 37, 'come': 38, 'play': 39, 'find': 40, 'life': 41, 'seem': 42, 'plot': 43, 'work': 44, 'actor': 45, 'two': 46, 'many': 47, 'year': 48, 'never': 49, 'want': 50, 'best': 51, 'little': 52, 'try': 53, 'ever': 54, 'man': 55, 'still': 56, 'part': 57, 'something': 58, 'director': 59, 'old': 60, 'back': 61, 'use': 62, 'funny': 63, 'lot': 64, 'real': 65, 'guy': 66, 'performance': 67, 'woman': 68, 'though': 69, 'feel': 70, 'star': 71, 'another': 72, 'big': 73, 'cast': 74, 'actually': 75, 'nothing': 76, 'new': 77, 'role': 78, 'young': 79, 'tell': 80, 'start': 81, 'write': 82, 'point': 83, 'every': 84, 'leave': 85, 'day': 86, 'world': 87, 'girl': 88, 'set': 89, 'horror': 90, 'turn': 91, 'minute': 92, 'comedy': 93, 'u': 94, 'long': 95, 'fact': 96, 'quite': 97, 'pretty': 98, 'action': 99, 'around': 100, 'kill': 101, 'however': 102, 'right': 103, 'enough': 104, 'line': 105, 'fan': 106, 'live': 107, 'may': 108, 'become': 109, 'happen': 110, 'must': 111, 'need': 112, 'series': 113, 'script': 114, 'music': 115, 'without': 116, 'original': 117, 'saw': 118, 'keep': 119, 'family': 120, 'always': 121, 'almost': 122, 'kid': 123, 'put': 124, 'do': 125, 'begin': 126, 'whole': 127, 'least': 128, 'enjoy': 129, 'believe': 130, 'last': 131, 'bit': 132, 'mean': 133, 'far': 134, 'place': 135, 'friend': 136, 'laugh': 137, 'lead': 138, 'effect': 139, 'kind': 140, 'reason': 141, 'might': 142, 'call': 143, 'anything': 144, 'since': 145, 'tv': 146, 'book': 147, 'let': 148, 'probably': 149, 'run': 150, 'child': 151, 'screen': 152, 'name': 153, 'away': 154, 'hard': 155, 'yet': 156, 'shot': 157, 'moment': 158, 'fun': 159, 'anyone': 160, 'help': 161, 'sure': 162, 'rather': 163, 'audience': 164, 'american': 165, 'idea': 166, 'war': 167, 'high': 168, 'dvd': 169, 'although': 170, 'especially': 171, 'read': 172, 'expect': 173, 'interest': 174, 'course': 175, 'everything': 176, 'job': 177, 'move': 178, 'maybe': 179, 'three': 180, 'sense': 181, 'mind': 182, 'worth': 183, 'different': 184, 'someone': 185, 'sound': 186, 'main': 187, 'problem': 188, 'night': 189, 'face': 190, 'true': 191, 'version': 192, 'money': 193, 'episode': 194, 'second': 195, 'everyone': 196, 'together': 197, 'follow': 198, 'black': 199, 'half': 200, 'instead': 201, 'hour': 202, 'special': 203, 'death': 204, 'short': 205, 'lose': 206, 'house': 207, 'recommend': 208, 'john': 209, 'eye': 210, 'talk': 211, 'wife': 212, 'beautiful': 213, 'head': 214, 'fall': 215, 'waste': 216, 'miss': 217, 'low': 218, 'later': 219, 'direct': 220, 'excellent': 221, 'classic': 222, 'hand': 223, 'budget': 224, 'boy': 225, 'father': 226, 'change': 227, 'else': 228, 'view': 229, 'production': 230, 'top': 231, 'piece': 232, 'fight': 233, 'viewer': 234, 'include': 235, 'nice': 236, 'poor': 237, 'remember': 238, 'release': 239, 'simply': 240, 'completely': 241, 'home': 242, 'picture': 243, 'men': 244, 'appear': 245, 'open': 246, 'less': 247, 'couple': 248, 'camera': 249, 'others': 250, 'understand': 251, 'die': 252, 'human': 253, 'along': 254, 'attempt': 255, 'word': 256, 'feature': 257, 'care': 258, 'dead': 259, 'hollywood': 260, 'school': 261, 'video': 262, 'song': 263, 'either': 264, 'wrong': 265, 'suppose': 266, 'stupid': 267, 'full': 268, 'title': 269, 'rest': 270, 'lack': 271, 'add': 272, 'next': 273, 'game': 274, 'early': 275, 'writer': 276, 'sex': 277, 'truly': 278, 'style': 279, 'small': 280, 'awful': 281, 'person': 282, 'interesting': 283, 'murder': 284, 'save': 285, 'meet': 286, 'sort': 287, 'mother': 288, 'terrible': 289, 'case': 290, 'review': 291, 'flick': 292, 'perhaps': 293, 'dialo ...

# %% [markdown]
# # Setting up vocab size for word2vec handling

# %%
'''
SELECT TOP 20K dict
'''



from itertools import islice

def take(n, iterable):
    "Return first n items of the iterable as a list"
    return dict(islice(iterable, n))

vocab_20k = take(VOCAB_SIZE, total_vocab.items())


type(vocab_20k)
# Out:
# dict

# %%
print(len(vocab_20k))
# Out:
# 20000

# %% [markdown]
# # Converting text data to abv to integer values

# %%
# %%time
seq = tokenizer.texts_to_sequences(df["review"])
# Out:
# Wall time: 4.14 s

# %% [markdown]
# # Check for values

# %%
 df['review'][155]
# Out:
# 'movie ups downs good stuff movie much outweighs bad good movie indeed sometimes dialogue sound light one noticed way set light amateur act good highly original storyline intense atmosphere gore factor high effect do supremely definitely worth watch maybe even must see horror gore fan'

# %%
np.array(seq[155])
# Out:
# array([   1, 1516,    8,  392,    1,   24,   17,    8,    1,  706,  414,
#         294,  186,  313,    3, 4703,   34,   89,  313, 1865,   36,    8,
#         423,  117,  623, 1311,  694,  461, 1567,  168,  139,  125, 7979,
#         312,  183,   14,  179,   15,  111,    6,   90,  461,  106])

# %%
'''
WE CAN SEE THE DIFFERENCE 10 , BCOZ OTHER VALUES ARE GRATER THEN VOCAB SIZE 20000 ; SO ITS NOT CONSIDERED
'''
print(df['word_count'][155])
print(len(np.array(seq[155])))
# Out:
# 45
# 43

# %%
print(" Actual VOCAB_SIZE deined: ",VOCAB_SIZE)
print(" Actual tokens created: ",len(tokenizer.word_index))# IF WE WANT TO CONSIDER EVERY TEXT IN VOCAB PASS THIS
# Out:
#  Actual VOCAB_SIZE deined:  20000
#  Actual tokens created:  91671

# %% [markdown]
# # Deciding Vocabulary for EMB. matrix
# * we can load either 100dims, 300dims * VOCAB_SIZE_new

# %% [markdown]
# # Importing pre trained Word2Vec
# * https://blog.keras.io/using-pre-trained-word-embeddings-in-a-keras-model.html

# %%
# %%time
Word2Vec_Embedding = {}#dict()
                                                          #100d
f = open('D:/dataset/Embedding/Word2Vec/GoogleNews-vectors-negative300.txt', encoding="utf8")

for line in f:
	values = line.split() # split by lines
	word = values[0]# get 1st word in the line i.e the "word" itself
	coefs = np.asarray(values[1:], dtype='float32') # the preceding vector is the vector itself
	Word2Vec_Embedding[word] = coefs# its a dict of word(key) and vector(value)
f.close()

print('Loaded %s word vectors.' % len(Word2Vec_Embedding))
# Out:
# Loaded 1882621 word vectors.
# Wall time: 3min 56s

# %%
print(Word2Vec_Embedding.get("_beautiful","NULL"))
# Out:
# NULL

# %% [markdown]
# # Pre trained Word2Vec, used as initilzation for our task
# * we create 2D array of size (VOCAB_SIZE * 300)

# %%
#so we have to create 2d array
# 50 since we have loaded 100 embd layer Glove matrix
      #Setting up vocab size for GLOVE handling
embedding_matrix = np.zeros((VOCAB_SIZE+1,300))
##words_not_found = []   # words not found in Glove emb. w.r.t our data corpous
import collections
words_not_found = collections.defaultdict(list)

for word, i in vocab_20k.items():
    
    word2vec_vector_reprsentation = Word2Vec_Embedding.get(word,"NULL")
    if word2vec_vector_reprsentation != "NULL":
        embedding_matrix[i] = word2vec_vector_reprsentation
    else:
        ##words_not_found.append(word)
        words_not_found[word].append(i)
# Out:
# C:\Users\DBCE\Anaconda3\envs\tf_gpu\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if sys.path[0] == '':

# %%
words_not_found  #words not found in word2vec embedding; CAN USE WORDCLOUD
# Out:
# defaultdict(list,
#             {'illiant': [426],
#              'clichã': [561],
#              'humour': [993],
#              'ief': [1212],
#              'hitchcock': [1217],
#              'theatre': [1237],
#              'favourite': [1356],
#              'eaking': [1359],
#              '80': [1442],
#              'utal': [1526],
#              '70': [1537],
#              'oken': [1724],
#              'inging': [1745],
#              'eaks': [1755],
#              'keaton': [1798],
#              'realise': [1815],
#              'illiantly': [1850],
#              'seagal': [1874],
#              'tarzan': [1986],
#              'colour': [2079],
#              'eastwood': [2179],
#              'fulci': [2236],
#              'sinatra': [2256],
#              'wwii': [2285],
#              'columbo': [2415],
#              '60': [2472],
#              'sutherland': [2524],
#              'pacino': [2537],
#              'mst3k': [2550],
#              'stanwyck': [2569],
#              'bergman': [2588],
#              'flynn': [2618],
#              'connery': [2651],
#              '1950s': [2664],
#              'tarantino': [2670],
#              'eathtaking': [2674],
#              'welles': [2677],
#              '20th': [2763],
#              'matthau': [2780],
#              '1970s': [2785],
#              'iefly': [2812],
#              'lugosi': [2825],
#              'grey': [2828],
#              'fiancã': [2838],
#              'spielberg': [2872],
#              'idge': [2926],
#              'austen': [2989],
#              '1980s': [2995],
#              'illiance': [3050],
#              'carrey': [3125],
#              'walken': [3134],
#              'davy': [3136],
#              'brando': [3157],
#              'fonda': [3171],
#              'streep': [3197],
#              'altman': [3219],
#              'oadcast': [3243],
#              'cusack': [3262],
#              'argento': [3266],
#              'sandler': [3292],
#              'griffith': [3295],
#              'branagh': [3328],
#              'ains': [3339],
#              '50': [3382],
#              'damme': [3415],
#              '90': [3479],
#              'troma': [3522],
#              'custer': [3562],
#              'cassavetes': [3563],
#              'cagney': [3565],
#              'centre': [3575],
#              'streisand': [3596],
#              'karloff': [3599],
#              'nicholson': [3623],
#              'bronson': [3642],
#              'francisco': [3645],
#              'lemmon': [3662],
#              '1930s': [3676],
#              'utally': [3692],
#              'garfield': [3696],
#              'miyazaki': [3718],
#              'huston': [3735],
#              'favour': [3749],
#              '13th': [3750],
#              'niro': [3777],
#              'carradine': [3778],
#              '1960s': [3810],
#              'corman': [3866],
#              'falk': [3890],
#              'behaviour': [3947],
#              'meryl': [3954],
#              'programme': [3977],
#              'quaid': [4000],
#              'foxx': [4015],
#              'ritter': [4041],
#              'romero': [4047],
#              'widmark': [4062],
#              'gere': [4065],
#              '19th': [4124],
#              'voight': [4149],
#              'bettie': [4151],
#              'iel': [4221],
#              'barrymore': [4231],
#              'erika': [4232],
#              'miike': [4241],
#              'elvira': [4243],
#              'sarandon': [4258],
#              'hartley': [4268],
#              'uwe': [4281],
#              'heston': [4282],
#              'irene': [4298],
#              'denzel': [4303],
#              'olivier': [4348],
#              'macbeth': [4361],
#              'astaire': [4367],
#              'belushi': [4369],
#              'rourke': [4391],
#              'ponyo': [4409],
#              '40': [4516],
#              'beatty': [4518],
#              'mildred': [4523],
#              'utality': [4548],
#              '1940s': [4574],
#              'travolta': [4575],
#              '30': [4596],
#              'brosnan': [4603],
#              'herzog': [4611],
#              'mitchum': [4664],
#              'dillon': [4675],
#              'cushing': [4682],
#              'orson': [4701],
#              'busey': [4715],
#              'coppola': [4726],
#              'clooney': [4744],
#              'akshay': [4750],
#              'kidman': [4754],
#              'hayworth': [4774],
#              'kurtz': [4790],
#              'errol': [4799],
#              'paxton': [4805],
#              'quentin': [4812],
#              'bakshi': [4822],
#              'stallone': [4826],
#              '21st': [4861],
#              'carell': [4863],
#              'dunne': [4865],
#              'duvall': [4882],
#              'paulie': [4892],
#              'fulfil': [4907],
#              'verhoeven': [4920],
#              'deniro': [4921],
#              'axe': [4927],
#              'amitabh': [4942],
#              'neill': [4958],
#              'leland': [4966],
#              'lionel': [4968],
#              'polanski': [4969],
#              'costello': [4975],
#              'devito': [4996],
#              'downey': [5002],
#              'hepburn': [5003],
#              'palma': [5013],
#              'pfeiffer': [5017],
#              'kline': [5019],
#              'shatner': [5028],
#              'uptly': [5059],
#              'doris': [5073],
#              'characterisation': [5096],
#              'nolte': [5097],
#              'eyre': [5103],
#              'randolph': [5124],
#              'antonioni': [5126],
#              'sherlock': [5129],
#              'toole': [5133],
#              'recognise': [5138],
#              'scorsese': [5147],
#              'haines': [5161],
#              'eisenstein': [5168],
#              'ingrid': [5186],
#              'preminger': [5196],
#              'clive': [5207],
#              'visconti': [5213],
#              'enthral': [5222],
#              'nicolas': [5229],
#              'melville': [5236],
#              'macarthur': [5241],
#              'farrell': [5254],
#              'isabelle': [5260],
#              'neighbour': [5262],
#              'portman': [5299],
#              'rhett': [5304],
#              'ricci': [5305],
#              'mencia': [5315],
#              'swayze': [5318],
#              'laurence': [5329],
#              'jules': [5332],
#              'palance': [5334],
#              'eakdown': [5340],
#              'cassidy': [5354],
#              'kurosawa': [5357],
#              'aham': [5366],
#              'segal': [5379],
#              'ooding': [5401],
#              'malone': [5436],
#              'basinger': [5445],
#              'depardieu': [5453],
#              'juliette': [5466],
#              'affleck': [5467],
#              'ainless': [5478],
#              'ebert': [5479],
#              'marlon': [5485],
#              'ustinov': [5522],
#              'redford': [5523],
#              'overbear': [5524],
#              'kermit': [5536],
#              'dolph': [5550],
#              'paltrow': [5560],
#              'othello': [5567],
#              'madsen': [5569],
#              'lundgren': [5619],
#              'alvin': [5624],
#              'knightley': [5667],
#              'sirk': [5672],
#              'eathing': [5673],
#              'farley': [5690],
#              'lucille': [5698],
#              '1990s': [5703],
#              'arquette': [5730],
#              'lumet': [5735],
#              'monkees': [5741],
#              'aztec': [5780],
#              'kinnear': [5785],
#              'vaughn': [5788],
#              'vivian': [5800],
#              'kilmer': [5807],
#              'bacall': [5810],
#              'soderbergh': [5827],
#              'zane': [5831],
#              'willard': [5844],
#              'lupino': [5846],
#              'kinski': [5856],
#              'granger': [5863],
#              'gromit': [5868],
#              'gundam': [5870],
#              'niven': [5899],
#              'christy': [5902],
#              'malkovich': [5911],
#              'lansbury': [5920],
#              'costner': [5922],
#              'brien': [5925],
#              'penelope': [5931],
#              'excruciate': [5936],
#              'cheadle': [5944],
#              'claus': [5959],
#              'fontaine': [5987],
#              'rukh': [5998],
#              'lucio': [6004],
#              'cronenberg': [6010],
#              'kaufman': [6017],
#              'timberlake': [6038],
#              'grier': [6062],
#              'glenda': [6068],
#              'vance': [6079],
#              'chaney': [6092],
#              'shemp': [6105],
#              'timon': [6114],
#              'whoopi': [6121],
#              'gein': [6143],
#              'fiennes': [6151],
#              'coburn': [6165],
#              'gamera': [6166],
#              'attenborough': [6171],
#              'iâ': [6192],
#              'bunuel': [6210],
#              'kristofferson': [6214],
#              'tierney': [6218],
#              'hackman': [6231],
#              'judgement': [6241],
#              'seinfeld': [6265],
#              'mclaglen': [6276],
#              'lestat': [6290],
#              'govinda': [6291],
#              'fassbinder': [6310],
#              'fishburne': [6314],
#              'hawke': [6329],
#              'antwone': [6335],
#              'biko': [6336],
#              'godard': [6338],
#              'wayans': [6339],
#              'evelyn': [6347],
#              'myrna': [6356],
#              'dietrich': [6359],
#              'poirot': [6360],
#              'finney': [6375],
#              'ramon': [6379],
#              'lorre': [6380],
#              'audrey': [6387],
#              'henson': [6394],
#              'redgrave': [6395],
#              'pickford': [6401],
#              'fellini': [6402],
#              'keanu': [6412],
#              'chupaca': [6414],
#              'naschy': [6415],
#              'corbett': [6418],
#              'elmer': [6423],
#              'gillian': [6430],
#              'zellweger': [6432],
#              'esther': [6437],
#              'jodie': [6441],
#              'kingsley': [6448],
#              'edmund': [6449],
#              'tilly': [6455],
#              'honour': [6459],
#              'rathbone': [6462],
#              'boyer': [6463],
#              'zoey': [6473],
#              'mcqueen': [6477],
#              'nielsen': [6479],
#              'dahmer': [6481],
#              'huppert': [6484],
#              'zizek': [6485],
#              'vader': [6500],
#              'capote': [6516],
#              'moriarty': [6522],
#              'loretta': [6532],
#              'gershwin': [6539],
#              'brynner': [6546],
#              'warhol': [6561],
#              'faye': [6569],
#              'gulliver': [6580],
#              'ramones': [6582],
#              'bava': [6586],
#              'casablanca': [6587],
#              '18th': [6612],
#              'schwarzenegger': [6613],
#              'babette': [6619],
#              'deneuve': [6628],
#              'demille': [6637],
#              'dudley': [6643],
#              'winchester': [6644],
#              'thurman': [6659],
#              'caligula': [6669],
#              'gielgud': [6677],
#              'truman': [6678],
#              'vincenzo': [6689],
#              'deanna': [6694],
#              'eathe': [6697],
#              'bachchan': [6702],
#              'beethoven': [6704],
#              'zombi': [6718],
#              'elijah': [6719],
#              'amato': [6731],
#              'cecil': [6738],
#              'kathryn': [6761],
#              'swanson': [6766],
#              'lubitsch': [6784],
#              'kolchak': [6792],
#              'gã': [6800],
#              'impend': [6802],
#              'rko': [6830],
#              'harriet': [6840],
#              'lorenzo': [6841],
#              'dien': [6855],
#              'rhys': [6859],
#              'marlow': [6869],
#              'dafoe': [6871],
#              'theodore': [6881],
#              'marvellous': [6884],
#              'selleck': [6889],
#              'vinnie': [6894],
#              'sheridan': [6895],
#              'edith': [6902],
#              'dario': [6905],
#              'rickman': [6918],
#              'jagger': [6921],
#              'martino': [6925],
#              'milland': [6932],
#              'andreas': [6938],
#              'beowulf': [6939],
#              'geoffrey': [6940],
#              'eleanor': [6944],
#              'poitier': [6949],
#              'kazan': [6963],
#              'fairbanks': [6972],
#              'masterson': [6982],
#              'estevez': [6987],
#              'duchovny': [6990],
#              'ratso': [6997],
#              'mabel': [6998],
#              'minnelli': [7003],
#              'wahlberg': [7042],
#              'goldblum': [7047],
#              'cedric': [7053],
#              'wynorski': [7057],
#              'farscape': [7060],
#              'rowlands': [7063],
#              'scheider': [7069],
#              'veronika': [7070],
#              'conroy': [7071],
#              'arkin': [7076],
#              'shakespearean': [7078],
#              'mcdowell': [7080],
#              'raines': [7101],
#              'sydow': [7110],
#              'atwill': [7115],
#              'fallon': [7121],
#              'gilliam': [7128],
#              'didnt': [7130],
#              'sylvester': [7131],
#              'midler': [7155],
#              'judd': [7170],
#              'eakfast': [7176],
#              'byrne': [7188],
#              'quigley': [7193],
#              'dolemite': [7197],
#              'coen': [7202],
#              'pegg': [7203],
#              'klaus': [7208],
#              'seuss': [7218],
#              'raimi': [7245],
#              'arnie': [7248],
#              'lukas': [7258],
#              'sammo': [7270],
#              'durbin': [7294],
#              'kansa': [7306],
#              'clarence': [7308],
#              'krueger': [7311],
#              'silverman': [7319],
#              'sã': [7352],
#              'mathieu': [7358],
#              'galactica': [7376],
#              'crowe': [7378],
#              'schumacher': [7381],
#              'carlyle': [7386],
#              'harlow': [7397],
#              'lili': [7398],
#              'sheba': [7399],
#              'alexandre': [7404],
#              'rosario': [7407],
#              'dassin': [7425],
#              'dressler': [7426],
#              'geraldine': [7439],
#              'nathaniel': [7455],
#              'patton': [7459],
#              'chiba': [7462],
#              'gilmore': [7467],
#              'dã': [7468],
#              'easts': [7477],
#              'thelma': [7482],
#              '1920s': [7486],
#              'ironside': [7492],
#              'bynes': [7512],
#              'zorro': [7513],
#              'bandw': [7514],
#              'crispin': [7516],
#              'natasha': [7518],
#              'massey': [7521],
#              'priscilla': [7523],
#              'unette': [7525],
#              'wendigo': [7528],
#              'truffaut': [7539],
#              'jacobi': [7547],
#              'darth': [7559],
#              'agatha': [7571],
#              'reiser': [7572],
#              'aniston': [7578],
#              'bergen': [7583],
#              'pryor': [7608],
#              'adele': [7610],
#              'colman': [7617],
#              'carole': [7618],
#              'emilio': [7629],
#              'kutcher': [7637],
#              'mulholland': [7663],
#              'raoul': [7671],
#              'anch': [7676],
#              'carnosaur': [7678],
#              'concorde': [7683],
#              'carlito': [7685],
#              'ripley': [7687],
#              'gunga': [7694],
#              'goldsworthy': [7695],
#              'capshaw': [7696],
#              'schrader': [7697],
#              'soylent': [7710],
#              'keira': [7714],
#              'helsing': [7742],
#              'manson': [7746],
#              'eakthrough': [7749],
#              'katharine': [7767],
#              'sosuke': [7775],
#              'cleopatra': [7778],
#              'byron': [7787],
#              'dreyfus': [7790],
#              'rockne': [7792],
#              'josie': [7797],
#              'bsg': [7799],
#              'keitel': [7847],
#              'semitism': [7850],
#              'prue': [7852],
#              'komodo': [7856],
#              'alain': [7872],
#              'marisa': [7880],
#              'kieslowski': [7918],
#              'mendes': [7922],
#              'labour': [7923],
#              'hadley': [7925],
#              'hannibal': [7935],
#              'langdon': [7942],
#              'brigitte': [7957],
#              'stalingrad': [7959],
#              'caron': [7961],
#              'cassel': [7962],
#              'liotta': [7964],
#              'milligan': [7965],
#              'valerie': [7976],
#              'gwyneth': [7985],
#              'northam': [7996],
#              'melvyn': [8011],
#              'marlene': [8012],
#              'colourful': [8016],
#              'talbot': [8028],
#              'pauline': [8034],
#              'sonja': [8040],
#              'mã': [8043],
#              'binoche': [8046],
#              'englund': [8049],
#              'mishima': [8050],
#              'luther': [8054],
#              'rififi': [8055],
#              'amrita': [8070],
#              'rachael': [8073],
#              'elton': [8079],
#              'fleischer': [8089],
#              'delon': [8107],
#              'cimino': [8111],
#              'harlin': [8115],
#              'criticise': [8122],
#              'zucco': [8126],
#              'wwi': [8132],
#              'bardem': [8137],
#              'nevsky': [8150],
#              'tomei': [8158],
#              'demme': [8175],
#              'alejandro': [8178],
#              'connors': [8185],
#              'gypo': [8202],
#              'laputa': [8206],
#              'jacqueline': [8213],
#              'blondell': [8220],
#              'renoir': [8222],
#              'kiefer': [8224],
#              'paresh': [8227],
#              'eccleston': [8232],
#              'potemkin': [8241],
#              'beckinsale': [8256],
#              'bonham': [8259],
#              'flavia': [8275],
#              'capra': [8281],
#              'dillinger': [8302],
#              'philippe': [8310],
#              'dangerfield': [8311],
#              'takashi': [8314],
#              'gyllenhaal': [8325],
#              'rohmer': [8329],
#              'emmanuelle': [8343],
#              'werner': [8345],
#              'vargas': [8358],
#              'humphrey': [8359],
#              'maltin': [8368],
#              'cortez': [8371],
#              'cheech': [8381],
#              'giovanni': [8384],
#              'channing': [8390],
#              'kruger': [8396],
#              'gena': [8397],
#              'turturro': [8401],
#              'pumbaa': [8402],
#              'josã': [8404],
#              'longoria': [8412],
#              'hamill': [8434],
#              'defence': [8445],
#              'hasselhoff': [8446],
#              'greenstreet': [8452],
#              'collette': [8463],
#              'ferris': [8467],
#              'witherspoon': [8491],
#              'loren': [8492],
#              'marjorie': [8519],
#              'grady': [8520],
#              'moustache': [8522],
#              'suchet': [8531],
#              'townsend': [8533],
#              'reginald': [8536],
#              'perlman': [8539],
#              'bernsen': [8542],
#              'mulder': [8547],
#              'mamet': [8557],
#              'mcdermott': [8559],
#              'cafã': [8566],
#              'antoine': [8567],
#              'morgana': [8575],
#              'theron': [8587],
#              'franz': [8596],
#              'harlan': [8616],
#              'corbin': [8627],
#              'oppenheimer': [8644],
#              'iturbi': [8647],
#              'stockwell': [8648],
#              'sondra': [8657],
#              'ealing': [8659],
#              'belmondo': [8670],
#              'schreiber': [8675],
#              'sampedro': [8678],
#              'eileen': [8683],
#              'linnea': [8684],
#              'sykes': [8690],
#              'suzy': [8691],
#              'minghella': [8693],
#              'ferrell': [8712],
#              'pesci': [8736],
#              'evie': [8741],
#              'vinci': [8744],
#              'mattei': [8752],
#              'willem': [8758],
#              'johansson': [8770],
#              'gustav': [8772],
#              'lã': [8773],
#              'vonnegut': [8777],
#              'forsythe': [8781],
#              'oldboy': [8782],
#              'pertwee': [8787],
#              'gotham': [8793],
#              'fenton': [8797],
#              'grendel': [8798],
#              'myra': [8801],
#              '20': [8809],
#              'lamarr': [8812],
#              'helena': [8819],
#              'glamour': [8832],
#              'mpaa': [8844],
#              'farnsworth': [8847],
#              'kersey': [8869],
#              'cassandra': [8874],
#              'siegel': [8880],
#              'riddick': [8881],
#              'bogosian': [8891],
#              'caddyshack': [8892],
#              'leguizamo': [8895],
#              'benoit': [8898],
#              'savalas': [8903],
#              'radha': [8905],
#              'henriksen': [8906],
#              'giovanna': [8908],
#              'hartman': [8909],
#              'sybil': [8925],
#              'dickinson': [8928],
#              'sergei': [8941],
#              'roeg': [8956],
#              'greenaway': [8967],
#              'carax': [8973],
#              'julianne': [8977],
#              'faulkner': [8982],
#              'hartnett': [8989],
#              'andie': [8991],
#              'depp': [8995],
#              'bronte': [9004],
#              'gracie': [9011],
#              'creasy': [9016],
#              'catalogue': [9022],
#              'mcgavin': [9036],
#              'cã': [9039],
#              'peckinpah': [9058],
#              'sigourney': [9084],
#              'razzie': [9085],
#              'cinemax': [9095],
#              'miriam': [9097],
#              'blaise': [9109],
#              'adamson': [9110],
#              'hearn': [9112],
#              'hermann': [9133],
#              'elisha': [9141],
#              'nichols': [9157],
#              'jed': [9161],
#              'haruhi': [9176],
#              'connelly': [9178],
#              'babs': [9204],
#              'cambodia': [9205],
#              'muriel': [9207],
#              'annette': [9209],
#              'daria': [9210],
#              'harron': [9216],
#              'elsa': [9217],
#              'malden': [9220],
#              'levinson': [9222],
#              'tatum': [9232],
#              'gackt': [9256],
#              'armand': [9265],
#              'macmurray': [9268],
#              'dourif': [9269],
#              'boyce': [9272],
#              'matinã': [9273],
#              'dicaprio': [9275],
#              'maguire': [9281],
#              'existenz': [9284],
#              'feinstone': [9297],
#              'cillian': [9300],
#              'rooker': [9301],
#              'ringwald': [9303],
#              'reba': [9324],
#              'himesh': [9335],
#              'pixote': [9338],
#              'natali': [9339],
#              'gretchen': [9341],
#              'poppins': [9342],
#              'guevara': [9346],
#              'protã': [9351],
#              'gino': [9354],
#              'fawcett': [9357],
#              'northfork': [9365],
#              'aschenbach': [9384],
#              'atkinson': [9388],
#              'blandings': [9399],
#              'kells': [9407],
#              'sorvino': [9409],
#              'terrence': [9421],
#              'tolkien': [9430],
#              'gannon': [9435],
#              'dudikoff': [9437],
#              'steiner': [9440],
#              'finlay': [9442],
#              'sholay': [9447],
#              'conway': [9454],
#              'schindler': [9457],
#              'popeye': [9464],
#              'pleasance': [9469],
#              'ramã³n': [9470],
#              'ichikawa': [9474],
#              'elisabeth': [9477],
#              'boorman': [9480],
#              'pauly': [9491],
#              'brashear': [9496],
#              'hedy': [9498],
#              'deol': [9504],
#              'neeson': [9511],
#              'rudolph': [9533],
#              'modine': [9538],
#              'grint': [9549],
#              'astin': [9550],
#              'gilligan': [9557],
#              'isabel': [9558],
#              'flatliners': [9567],
#              'phyllis': [9571],
#              'callahan': [9578],
#              'luzhin': [9590],
#              'agnes': [9593],
#              'aykroyd': [9612],
#              'almodovar': [9615],
#              'clouzot': [9616],
#              'claudius': [9624],
#              'kusturica': [9641],
#              '16mm': [9653],
#              'izzard': [9661],
#              'lyle': [9662],
#              'ricardo': [9673],
#              'raquel': [9676],
#              'ingmar': [9679],
#              'ullman': [9680],
#              'vito': [9695],
#              'caruso': [9699],
#              'darius': [9701],
#              'mirren': [9702],
#              'buscemi': [9703],
#              'giamatti': [9705],
#              'danning': [9709],
#              'grahame': [9721],
#              'selma': [9733],
#              'igor': [9734],
#              'tamura': [9735],
#              'rawal': [9740],
#              'zucker': [9744],
#              'gertrude': [9748],
#              'amityville': [9760],
#              'rã': [9762],
#              'newhart': [9769],
#              'wentworth': [9789],
#              'crichton': [9793],
#              'candice': [9794],
#              'savini': [9798],
#              'eezy': [9803],
#              'peralta': [9812],
#              'tyrone': [9819],
#              'mckenna': [9833],
#              'arden': [9835],
#              'tashan': [9843],
#              'geena': [9846],
#              'epps': [9849],
#              'ewoks': [9858],
#              'gandolfini': [9863],
#              'linney': [9866],
#              'caprica': [9867],
#              'heche': [9869],
#              'leila': [9871],
#              'lithgow': [9874],
#              'dunst': [9885],
#              'camille': [9897],
#              'sandm': [9900],
#              'morricone': [9902],
#              'landis': [9908],
#              'johnnie': [9920],
#              'mcintire': [9921],
#              'chã': [9922],
#              'olen': [9935],
#              'scully': [9936],
#              'naã': [9940],
#              'peebles': [9954],
#              'ringu': [9956],
#              'ribisi': [9958],
#              'bogdanovich': [9960],
#              'eathless': [9961],
#              'tarkovsky': [9962],
#              'dunaway': [9970],
#              'mcclure': [9980],
#              'gellar': [9981],
#              'prospero': [9985],
#              'cruella': [9986],
#              'rumour': [9991],
#              'hynkel': [10010],
#              'farrah': [10014],
#              'jã': [10022],
#              'veidt': [10025],
#              'bruckheimer': [10041],
#              'aiello': [10045],
#              'celine': [10049],
#              'ozu': [10054],
#              'underdevelop': [10056],
#              'tanya': [10060],
#              'darko': [10075],
#              'thunderball': [10076],
#              'fujimori': [10085],
#              'leachman': [10089],
#              'mantegna': [10098],
#              'leopold': [10100],
#              'stowe': [10101],
#              'mcgregor': [10102],
#              'osborne': [10114],
#              'sympathise': [10125],
#              'vidor': [10130],
#              'viggo': [10132],
#              'shahrukh': [10137],
#              'ladd': [10146],
#              'sammi': [10148],
#              'zelah': [10150],
#              'lumumba': [10155],
#              'statham': [10158],
#              'fagin': [10159],
#              'moreau': [10162],
#              'ernst': [10164],
#              'ainwashed': [10165],
#              'charlize': [10166],
#              'northanger': [10173],
#              'cartman': [10175],
#              'gleason': [10176],
#              'cartwright': [10180],
#              'cheyenne': [10186],
#              'pavarotti': [10188],
#              'culkin': [10205],
#              'hauser': [10235],
#              'molina': [10236],
#              'tng': [10238],
#              'blythe': [10245],
#              'crenna': [10246],
#              'kareena': [10257],
#              'lindbergh': [10259],
#              'adrienne': [10268],
#              'curtiz': [10272],
#              'lotr': [10274],
#              'eeding': [10275],
#              'raveena': [10276],
#              'hanzo': [10278],
#              'panahi': [10282],
#              'haim': [10289],
#              'depalma': [10294],
#              'shabana': [10295],
#              'danton': [10297],
#              'mastroianni': [10301],
#              'liza': [10305],
#              'spoilt': [10306],
#              'strangelove': [10318],
#              'dukakis': [10328],
#              'tsui': [10343],
#              'shawshank': [10345],
#              'varma': [10348],
#              'mcadams': [10358],
#              'gwtw': [10361],
#              'favourites': [10378],
#              'havilland': [10380],
#              'portia': [10383],
#              'bethany': [10385],
#              'horton': [10386],
#              'harilal': [10402],
#              'verne': [10409],
#              'forster': [10418],
#              'jovi': [10424],
#              'hitchcockian': [10425],
#              'mortensen': [10428],
#              'rizzo': [10430],
#              'loomis': [10431],
#              'noam': [10433],
#              'roscoe': [10437],
#              'swope': [10446],
#              'simba': [10447],
#              'haneke': [10448],
#              'maugham': [10449],
#              'stoltz': [10450],
#              'sloane': [10454],
#              'se7en': [10456],
#              'kalifornia': [10458],
#              'crowhurst': [10460],
#              'jouvet': [10462],
#              'berenger': [10468],
#              'watkins': [10472],
#              'dench': [10473],
#              'winslet': [10474],
#              'jekyll': [10479],
#              'matheson': [10486],
#              'rigg': [10490],
#              'frederic': [10491],
#              'pã': [10495],
#              'eleniak': [10501],
#              'othel': [10502],
#              'connolly': [10503],
#              'tromeo': [10505],
#              'amadeus': [10516],
#              'lacklustre': [10520],
#              'wenders': [10526],
#              'francois': [10544],
#              'qanda': [10546],
#              'yuzna': [10551],
#              'maclean': [10558],
#              'gossett': [10559],
#              'floriane': [10561],
#              'owsing': [10570],
#              'jeanette': [10585],
#              'champlain': [10592],
#              'culp': [10599],
#              'dibiase': [10601],
#              'damian': [10603],
#              'kronk': [10611],
#              'rosenstrasse': [10612],
#              'sherri': [10619],
#              'ossessione': [10625],
#              'azaria': [10626],
#              '11th': [10631],
#              'cotten': [10632],
#              'hayward': [10640],
#              'dogtown': [10653],
#              'tadzio': [10654],
#              'vittorio': [10663],
#              'changi': [10665],
#              'andersson': [10668],
#              'foch': [10673],
#              'freudian': [10674],
#              'luthor': [10678],
#              'corleone': [10682],
#              'schlesinger': [10695],
#              'hiroshima': [10703],
#              'wallach': [10704],
#              'blaine': [10708],
#              'jerker': [10721],
#              'eeze': [10723],
#              'terence': [10724],
#              'flavour': [10728],
#              'deluise': [10730],
#              'carface': [10731],
#              'bulgaria': [10751],
#              'trancers': [10758],
#              'mostel': [10761],
#              'guttenberg': [10766],
#              'shue': [10767],
#              'pasolini': [10769],
#              'lillian': [10775],
#              'jansen': [10781],
#              'montand': [10782],
#              'nadia': [10785],
#              'kornbluth': [10789],
#              'lanza': [10790],
#              'ifc': [10791],
#              'dundee': [10793],
#              'odessa': [10802],
#              'koontz': [10805],
#              'coolio': [10815],
#              'elli': [10822],
#              'courtenay': [10832],
#              'mahmut': [10864],
#              'joline': [10868],
#              'yugoslavia': [10872],
#              'pyun': [10873],
#              'aweigh': [10876],
#              ...})

# %%
print(len(words_not_found))
# Out:
# 3197

# %%
embedding_matrix.shape # Embedding layer matrix
# Out:
# (20001, 300)

# %% [markdown]
# # Padding and Truncating Data
# * To feed it to N.N, inputs to have the same length
#  - Either we ensure that all sequences in the entire data-set have the same length
#  - Or Entier batch should be of same length
# * Going about choosing ampunt to pad
#  - going with longest seq, would be just waste of memory for texr whose length is small
#  - going with smalles seq , would be just ignoring other imp values
#  - so we go optimal

# %%
'''
All that the Embedding layer does is to map the integer inputs to the vectors found at the corresponding index in the 
embedding matrix, i.e. the sequence [1, 2] would be converted to [embeddings[1], embeddings[2]]
'''
print(np.array(seq[506]))
# Out:
# [    8  1337    13    25   103  1709    14    92     1  3217 12926   106
#     14   199   335     1    52   294  3589  2928   240    14   289   744
#    199   335     1    52   294     1   110    32  6941   151   396    76
#     25   249   224   148   124    24  2090  2222   152   494   585    81
#      2    92    95  1189   879   157   131   195   940    92    59    35
#    186   340  4598  1407   322    72   157   346   232   732   229   158
#     88  1401    81 11214  2969   373   246    21     2  1419    28   336
#      9    91  1385   128    92   184  2969   543   100  9786  3569   903
#   6848   577   244    28     9    32  1435    32     1   349  5264  2426
#   1293   147  1410  2506  2792   515    92    32 12926   106   148   444
#    182  1368    25     2  1934   384   232  1865   909   508  1979 14507
#   2608    55  1443   603   232  3031   199   335  7292]

# %%
np.max(np.array(seq[506]))
# Out:
# 14507

# %% [markdown]
# # Padding and trucating here

# %%
imdb_data_pad = sequence.pad_sequences(seq , maxlen=INPUT_TEXT_LENGTH,padding='pre', truncating='pre')

# %%
imdb_data_pad.shape
# 2k review
# and 695 fixed I/P shape
# Out:
# (49999, 294)

# %%
#checking
#imdb_data_pad[4]
type(seq)
# Out:
# list

# %%
tokenizer

# %% [markdown]
# # Tokenizer Inverse Map

# %%
idx = tokenizer.word_index
inverse_map = dict(zip(idx.values(), idx.keys()))

# %%
def tokens_to_string(tokens):
    # Map from tokens back to words.
    words = [inverse_map[token] for token in tokens if token != 0]
    
    # Concatenate all words.
    text = " ".join(words)

    return text

# %%
tokens_to_string(seq[506])
# Out:
# 'good lord go say right bat watch minute movie hardcore eraserhead fan watch black white movie little dialogue defense apply simply watch terrible weird black white movie little dialogue movie happen give goth child talent nothing say camera budget let put much offensive imagery screen possible clear start film minute long assume exist shot last second drag minute director love sound voice syndrome refuse cut another shot entire piece footage view moment girl mask start masturbate corpse god open scene film joy know matter time turn tape least minute different corpse pull around twitch rope gang cloak mystery men know time give rarely give movie sit entirety blair witch book shadow albeit happily deserve minute give eraserhead fan let simple mind comparison say film con rent piece amateur trash allow refer tetsuo iron man watchable enjoyable piece incoherent black white weirdness'

# %%
# N.N Model
len(tokenizer.word_index) # This are total word in dict
#it depends if i want to use entier dict or only few occuring word
# Out:
# 91671

# %% [markdown]
# # Split data to test/ train / dev (disabled for train test split )

# %%
X= imdb_data_pad #PADDED VERSION OF DATA
y= df['sentiment'] # LABELS OF DATA

X_train, X_val, y_train, y_val = train_test_split( X, y, test_size=0.30,stratify=y, random_state=42)                #30%
#  #4%

# %% [markdown]
# **Reason for starified split:**
# https://stats.stackexchange.com/questions/250273/benefits-of-stratified-vs-random-sampling-for-generating-training-data-in-classi

# %%
#Stratiy on y_train data
X_train,X_test,y_train,y_test = train_test_split( X_train, y_train, test_size=0.04,stratify=y_train, random_state=42)

# %%
print("Train data:",len(X_train),'  ',len(y_train))
print("Validation data:",len(X_val),'  ',len(y_val))
print("Test data:",len(X_test),'  ',len(y_test))
print(type(y_train))

X_train = np.asarray(X_train)
X_val = np.asarray(X_val)
X_test = np.asarray(X_test)

y_train = np.asarray(y_train)
y_val = np.asarray(y_val)
y_test = np.asarray(y_test)
# Out:
# Train data: 33599    33599
# Validation data: 15000    15000
# Test data: 1400    1400
# <class 'pandas.core.series.Series'>

# %%
y_test[155]
# Out:
# 0.0

# %% [markdown]
# # CREATING A MODEL
# * http://fizzylogic.nl/2017/05/08/monitor-progress-of-your-keras-based-neural-network-using-tensorboard/

# %%
# %%time
EMBEDDING_DIM = 300 #or 150

model = Sequential()

#model.add(Embedding(VOCAB_SIZE, EMBEDDING_DIM, input_length=INPUT_TEXT_LENGTH))

embedding_layer = Embedding(VOCAB_SIZE+1, EMBEDDING_DIM, weights=[embedding_matrix], input_length=INPUT_TEXT_LENGTH, 
                            trainable=True)
model.add(embedding_layer)
model.add(Dropout(0.2))
model.add(LSTM(units=100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# simple early stopping
ec = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
mc = ModelCheckpoint(MODEL_FILEPATH, monitor='val_acc', mode='max', verbose=1, save_best_only=True)
#mc = ModelCheckpoint(PROJ_NAME,'_best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

'''
embedding_layer = Embedding(VOCAB_SIZE, 50, weights=[embedding_matrix], input_length=INPUT_TEXT_LENGTH, trainable=False)
model.add(embedding_layer)
model.add(Dropout(0.2))
'''
'''model.add(CuDNNGRU(units=8, return_sequences=True))
model.add(Dropout(0.2))
model.add(CuDNNGRU(units=4))'''


print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 294, 300)          6000300
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 294, 300)          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               219648
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 6,220,077
# Trainable params: 6,220,077
# Non-trainable params: 0
# _________________________________________________________________
# None
# Wall time: 1.38 s

# %% [markdown]
# # print out model image

# %%
from keras.utils import plot_model
import os
#install graph viz locally 1st
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'# install 
plot_model(model, to_file=IMAGE_PATH)

# %% [markdown]
# # fitting model with validation data

# %%
# %%time
history = model.fit(X_train, y_train , epochs=4 , validation_data=(X_val, y_val),verbose=2, batch_size = 64, callbacks=[tensorboard, ec, mc])
# TENSORBOARD
# tensorboard --logdir logs/
# http://localhost:6006/
# Out:
# Train on 33599 samples, validate on 15000 samples
# Epoch 1/4
#  - 834s - loss: 0.4139 - acc: 0.8143 - val_loss: 0.3825 - val_acc: 0.8377
#
# Epoch 00001: val_acc improved from -inf to 0.83773, saving model to model_tokenizers_weights_and_json/3.0  Word2Vec_pretrained_300dims_20k_LSTM_best_model.json
# Epoch 2/4
#  - 772s - loss: 0.2691 - acc: 0.8936 - val_loss: 0.2771 - val_acc: 0.8950
#
# Epoch 00002: val_acc improved from 0.83773 to 0.89500, saving model to model_tokenizers_weights_and_json/3.0  Word2Vec_pretrained_300dims_20k_LSTM_best_model.json
# Epoch 3/4
#  - 574s - loss: 0.2021 - acc: 0.9245 - val_loss: 0.2676 - val_acc: 0.8935
#
# Epoch 00003: val_acc did not improve from 0.89500
# Epoch 4/4
#  - 295s - loss: 0.1433 - acc: 0.9488 - val_loss: 0.3130 - val_acc: 0.8931
#
# Epoch 00004: val_acc did not improve from 0.89500
# Wall time: 41min 32s

# %%
# plot train and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# # Evaluate on test data

# %%
# Final evaluation of the model

scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 88.00%

# %% [markdown]
# # TO DO after training¶

# %% [markdown]
# # export tokenizer and weights of model for production
# * If model has performed well.

# %%
# saving instace so word can be converted to int tokens
with open(TOKENIZER_FILEPATH, 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # saving keras model n weights

# %%
# serialize model to JSON
'''model_json = model.to_json()
with open(PROJ_NAME,"_model.json", "w") as json_file: #MODEL_FILEPATH
    json_file.write(model_json)'''
    
# serialize weights to HDF5
model.save_weights(WEIGHT_FILEPATH)
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
'''
Neural networks are stochastic, they can produce different results when the same model is fit on the same data.
This is mainly because of the random initial weights and the shuffling of patterns during mini-batch gradient descent. 
This means that any one scoring of a model is unreliable and we should estimate model skill based on an average of multiple runs.
'''
with open(TOKENIZER_FILEPATH, 'rb') as handle:
    prod_instance_tokenizer = pickle.load(handle)
# Out:
# '\nNeural networks are stochastic, they can produce different results when the same model is fit on the same data.\nThis is mainly because of the random initial weights and the shuffling of patterns during mini-batch gradient descent. \nThis means that any one scoring of a model is unreliable and we should estimate model skill based on an average of multiple runs.\n'

# %%
from keras.preprocessing.text import Tokenizer,text_to_word_sequence
result = text_to_word_sequence("This movie really sucks! Can I get my money back please")

print(result)
text_to_int= prod_instance.texts_to_sequences(result)
print(text_to_int)
# Out:
# ['this', 'movie', 'really', 'sucks', 'can', 'i', 'get', 'my', 'money', 'back', 'please']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-3add74af447a> in <module>
#       3
#       4 print(result)
# ----> 5 text_to_int= prod_instance.texts_to_sequences(result)
#       6 print(text_to_int)
#
# NameError: name 'prod_instance' is not defined

# %% [markdown]
# # Have to try:
# * include pre trained embedding before
# * set trainable param**
# * other architecture
# * hyperparam settings etc..

# %%
'''
'movie ups downs good stuff movie much outweighs bad good movie indeed sometimes dialogue sound light one noticed way 
set light amateur act good highly original 
storyline intense atmosphere gore factor high effect do supremely definitely worth watch maybe even must see horror gore fan'

#refs
# Delete the Keras model with these hyper-parameters from memory.
del model
    
# Clear the Keras session, otherwise it will keep adding new
# models to the same TensorFlow graph each time we create
# a model with a different set of hyper-parameters.
K.clear_session()
'''

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-1c4752333457> in <module>
# ----> 1 Keras.clear_session()
#
# NameError: name 'Keras' is not defined
